# %% [markdown]
# # Pandas Dashboard BoilerPlate

# %% [markdown]
# ## Load dashboard class

# %%
from dashboard import Dashboard #imports class from dashboard.py

# %% [markdown]
# ### 💥 Development tip
# * The code below auto reloads imported modules when making updates to external code without having to restart the kernel each time
# * Not needed to run anything, just helpful for quicker tool development
#
#
# https://ipython.org/ipython-doc/3/config/extensions/autoreload.html

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %% [markdown]
# ## Create Pandas Dataframe
#
#
# Open dataFrame manager

# %%
import subprocess
# Opens system File Manager
subprocess.Popen(["Python", "DataFrameManager.py"])

display() # show nothing instead of suprocess message

# %% [markdown]
# Pulling data file into a pandas dataFrame using the dataFrameManager tool

# %%
import pickle

# Load the DataFrame
with open(r"c:\Users\ratre\Documents\2_Python Scripts\dashboard\saved_dataframes\testData.pkl", 'rb') as f:
    testData_df = pickle.load(f)

# Now dataFrame testData_df is ready to use.
display(testData_df)
# Out:
#      unit_number  time_in_cycles  operational_setting_1  \
# 0              1               1                -0.0007
# 1              1               2                 0.0019
# 2              1               3                -0.0043
# 3              1               4                 0.0007
# 4              1               5                -0.0019
# ..           ...             ...                    ...
# 187            1             188                -0.0067
# 188            1             189                -0.0006
# 189            1             190                -0.0027
# 190            1             191                 0.0000
# 191            1             192                 0.0009
#
#      operational_setting_2  operational_setting_3  \
# 0                  -0.0004                    100
# 1                  -0.0003                    100
# 2                   0.0003                    100
# 3                   0.0000                    100
# ...

# %% [markdown]
# ## Load dashboard

# %% [markdown]
# Creates dashboard object from Dashboard Class:
# - Dashboard argument is a Pandas dataFrame

# %% [markdown]
# **🔹 Note:**
# Surface plot won't show if the data selected isn't 3 dimensional
# - In this example, I remove ```unit_number``` because it's a singular scalar and I wanted all plots to show without changing the dropdown

# %%
#only removed so surface plot shows without changing x-axis dropdown
testData_df.drop('unit_number', axis=1, inplace=True)

# Initialize the dashboard with DataFrames
dashboard = Dashboard(testData_df)
dashboard.display()
# Out:
# c:\Users\ratre\anaconda3\envs\recpy\lib\site-packages\jupyter_client\session.py:721: UserWarning:
#
# Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
# ...
